# %%
import pandas as pd
import numpy as np
from numpy import mean
from numpy import std
from preprocessing import preprocess
import h5py
import urllib.request
import re
from maayanlab_bioinformatics.harmonization import ncbi_genes
from get_symbol import get_symbol
from prediction_pipeline import *
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, Lasso

# %% [markdown]
# # Loading gene expression data

# %%
f = pd.read_csv('GSE156063_swab_gene_counts.csv.gz')
f.index = f.iloc[:, 0] # Make ENSG genes as row indexing 
f = f.iloc[:, 1:] # Remove first index column

# %%
f
# Out:
#                  RR057e_00202  RR057e_00080  RR057e_00287  RR057e_00753  \
# Unnamed: 0
# ENSG00000000003          1534           621          1903          2796
# ENSG00000000419           153           123           221           344
# ENSG00000000457           295           185           457           626
# ENSG00000000460            75           108           292           367
# ENSG00000000938            19           471          1843           284
# ...                       ...           ...           ...           ...
# ENSG00000287856            40            77           189            62
# ENSG00000288258             0            21             2            41
# ENSG00000288380            34             0             0             5
# ENSG00000288534           117            42           195           332
# ENSG00000288558            38            29            13            85
#
#                  RR057e_00751  RR057e_00520  RR057e_00505  RR057i_00083  \
# Unnamed: 0
# ...

# %%
# Normalize data 
norm = preprocess(f)

# %%
# Convert Ensembl number index to gene symbol
norm = get_symbol(norm)
norm
# Out:
#                  RR057e_00202  RR057e_00080  RR057e_00287  RR057e_00753  \
# TSPAN6               9.750394      8.431520      8.536410      9.230869
# DPM1                 6.127114      6.002366      5.249229      5.956564
# SCYL3                7.153231      6.591814      6.363691      6.867613
# C1orf112             4.997992      5.799738      5.683124      6.048044
# FGR                  2.879951      8.019425      8.486833      5.658744
# ...                       ...           ...           ...           ...
# ENSG00000287856      3.994869      5.268032      4.989002      3.355198
# ENSG00000288258      0.381253      3.128959      0.741362      2.778832
# ENSG00000288380      3.758763      0.257046      0.517748      0.877175
# TMX2-CTNND1          5.747578      4.250350      5.048791      5.911258
# DUS4L-BCAP29         3.921698      3.628963      1.447463      3.806909
#
#                  RR057e_00751  RR057e_00520  RR057e_00505  RR057i_00083  \
# ...

# %% [markdown]
# # Convert gene x sample --> pathway x sample
#
# For each Gene Ontology library in Enrichr, convert it to a binary matrix of pathways x genes.
# Then multiply the matrix of pathways x genes by the above genes x samples to get a pathways x samples matrix.

# %%
libraries = ['GO_Biological_Process_2018', 'GO_Molecular_Function_2018', 'GO_Cellular_Component_2018']

# %%
pathway_by_sample = h5py.File("pathway_by_sample", "w")

# %%
for lib in libraries: 
    function_to_genes, gene_set = gene_set_dictionaries(lib)
    common_genes = list(set(gene_set) & set(norm.index)) # genes in common
    binary_matrix = gs_binary_matrix(function_to_genes, gene_set).loc[common_genes]
    df = norm.loc[common_genes]
    path_by_sample = (binary_matrix.T).dot(df)
    print(lib)
    display(path_by_sample)
    
    # Save in HDF file 
    pathway_list = (pd.DataFrame(path_by_sample.index)).values.astype("S").tolist()
    sample_list = (pd.DataFrame(path_by_sample.columns)).values.astype("S").tolist()
    group = pathway_by_sample.create_group("covid_" + lib)
    group.create_dataset("path_by_sample", data=path_by_sample)
    group.create_dataset("pathways", data=pathway_list)
    group.create_dataset("samples", data=sample_list)
    
pathway_by_sample.close()
# Out:
# GO_Biological_Process_2018
#                                                     RR057e_00202  \
# positive regulation of posttranscriptional gene...     92.403124
# regulation of cell cycle process (GO:0010564)         544.592341
# angiotensin-activated signaling pathway (GO:003...     18.608192
# DNA-templated transcription, termination (GO:00...    688.946530
# regulation of protein sumoylation (GO:0033233)         95.869233
# ...                                                          ...
# positive regulation of mitochondrial membrane p...     38.117682
# tRNA aminoacylation for protein translation (GO...    155.987883
# tryptophan metabolic process (GO:0006568)              42.734931
# guanosine-containing compound metabolic process...    104.789489
# tRNA modification (GO:0006400)                        314.270359
#
#                                                     RR057e_00080  \
# positive regulation of posttranscriptional gene...     91.803923
# ...

# %% [markdown]
# # Ground truth data

# %%
gr_truth = pd.read_csv("GSE156063_series_matrix.txt", sep='\t')
gr_truth
# Out:
#                       !Sample_title  \
# 0             !Sample_geo_accession
# 1                    !Sample_status
# 2           !Sample_submission_date
# 3          !Sample_last_update_date
# 4                      !Sample_type
# 5             !Sample_channel_count
# 6           !Sample_source_name_ch1
# 7              !Sample_organism_ch1
# 8       !Sample_characteristics_ch1
# 9       !Sample_characteristics_ch1
# 10      !Sample_characteristics_ch1
# 11      !Sample_characteristics_ch1
# 12      !Sample_characteristics_ch1
# 13   !Sample_treatment_protocol_ch1
# 14      !Sample_growth_protocol_ch1
# 15             !Sample_molecule_ch1
# 16     !Sample_extract_protocol_ch1
# 17     !Sample_extract_protocol_ch1
# 18                !Sample_taxid_ch1
# 19              !Sample_description
# 20          !Sample_data_processing
# 21          !Sample_data_processing
# 22          !Sample_data_processing
# 23          !Sample_data_processing
# 24          !Sample_data_processing
# ...

# %%
gr_truth = gr_truth.iloc[10, 1:]
idx = [ "_".join(i.split("_")[:2]) for i in gr_truth.index ]
gr_truth.index = idx
gr_truth
# Out:
# RR057e_00202    sars-cov-2 rpm: NEG
# RR057e_00080    sars-cov-2 rpm: NEG
# RR057e_00287    sars-cov-2 rpm: NEG
# RR057e_00753    sars-cov-2 rpm: POS
# RR057e_00751    sars-cov-2 rpm: POS
#                        ...
# RR057e_00721    sars-cov-2 rpm: POS
# RR057e_00731    sars-cov-2 rpm: POS
# RR057e_00728    sars-cov-2 rpm: POS
# RR057i_00067    sars-cov-2 rpm: POS
# RR057i_00116    sars-cov-2 rpm: NEG
# Name: 10, Length: 234, dtype: object

# %%
gr_truth = pd.DataFrame(gr_truth).loc[norm.columns]
test = [ 1 if res[-3:] == 'POS' else 0 for res in gr_truth.iloc[:, 0] ]
gr_truth.iloc[:, 0] = test
gr_truth.columns = ["Truth"]
gr_truth
# Out:
#               Truth
# RR057e_00202      0
# RR057e_00080      0
# RR057e_00287      0
# RR057e_00753      1
# RR057e_00751      1
# ...             ...
# RR057e_00721      1
# RR057e_00731      1
# RR057e_00728      1
# RR057i_00067      1
# RR057i_00116      0
#
# [234 rows x 1 columns]

# %% [markdown]
# # Principle Component Analysis

# %%
# obtain data 
pathway_by_sample = h5py.File("pathway_by_sample", "r+")
bp = pathway_by_sample['covid_GO_Biological_Process_2018']
def h5py_to_list(lst):
    return [ str(i)[3:-2] for i in lst ]
bp_matrix = bp['path_by_sample']
bp_pathways = h5py_to_list(bp['pathways'])
bp_samples = h5py_to_list(bp['samples'])
bp_df = pd.DataFrame(bp_matrix, index=bp_pathways, columns=bp_samples)

# %%
bp_df
# Out:
#                                                     RR057e_00202  \
# positive regulation of posttranscriptional gene...     92.403124
# regulation of cell cycle process (GO:0010564)         544.592341
# angiotensin-activated signaling pathway (GO:003...     18.608192
# DNA-templated transcription, termination (GO:00...    688.946530
# regulation of protein sumoylation (GO:0033233)         95.869233
# ...                                                          ...
# positive regulation of mitochondrial membrane p...     38.117682
# tRNA aminoacylation for protein translation (GO...    155.987883
# tryptophan metabolic process (GO:0006568)              42.734931
# guanosine-containing compound metabolic process...    104.789489
# tRNA modification (GO:0006400)                        314.270359
#
#                                                     RR057e_00080  \
# positive regulation of posttranscriptional gene...     91.803923
# ...

# %%
# check for repeated pathways - there are none 
total_num_pathways = 0
set_pathways = set()
for key in list(pathway_by_sample.keys()):
    key_pathways = h5py_to_list(pathway_by_sample[key]['pathways'])
    total_num_pathways += len(key_pathways)
    set_pathways.update(set(key_pathways))
print(total_num_pathways)
print(len(set_pathways))
# Out:
# 6700
# 6700

# %%
# combine data 
frames = []
for key in list(pathway_by_sample.keys()):
    key_matrix = pathway_by_sample[key]['path_by_sample']
    key_pathways = h5py_to_list(pathway_by_sample[key]['pathways'])
    key_samples = h5py_to_list(pathway_by_sample[key]['samples'])
    key_df = pd.DataFrame(key_matrix, index=key_pathways, columns=key_samples)
    frames.append(key_df)
go_df = pd.concat(frames)
display(go_df)
# Out:
#                                                     RR057e_00202  \
# positive regulation of posttranscriptional gene...     92.403124
# regulation of cell cycle process (GO:0010564)         544.592341
# angiotensin-activated signaling pathway (GO:003...     18.608192
# DNA-templated transcription, termination (GO:00...    688.946530
# regulation of protein sumoylation (GO:0033233)         95.869233
# ...                                                          ...
# Ras GTPase binding (GO:0017016)                      1167.442866
# transcriptional activator activity, RNA polymer...    897.731751
# ubiquitin-like protein ligase binding (GO:0044389)   1980.068067
# sodium ion transmembrane transporter activity (...    301.886416
# annealing helicase activity (GO:0036310)               33.341069
#
#                                                     RR057e_00080  \
# positive regulation of posttranscriptional gene...     91.803923
# ...

# %% [markdown]
# ## Linear (OLS) Regression Model
# Testing using K-folds and cross-validation

# %%
# define the pipeline
steps = [('pca', PCA(n_components=0.95)), ('m', LogisticRegression())]
model = Pipeline(steps=steps)
# evaluate model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, bp_df.T, gr_truth.values.ravel(), scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# Accuracy: 0.835 (0.070)

# %%
# For combined GO matrix 
# define the pipeline
steps = [('pca', PCA(n_components=0.95)), ('m', LogisticRegression())]
model = Pipeline(steps=steps)
# evaluate model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, go_df.T, gr_truth.values.ravel(), scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# Accuracy: 0.848 (0.066)

# %% [markdown]
# ## Least Squares Multiple Regression Model

# %% [markdown]
# ## Lasso model

# %%
lasso_steps = [('pca', PCA(n_components=0.95)), ('m', Lasso(alpha=0))]
lasso = Pipeline(steps=lasso_steps)
lasso.fit(bp_df.T, gr_truth.values.ravel())
scores = cross_val_score(lasso, bp_df.T, gr_truth.values.ravel())
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/pipeline.py:250: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params)
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:477: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/pipeline.py:250: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# ...

# %%
import matplotlib.pylab as plt 
from sklearn.cross_validation import train_test_split 
from sklearn.linear_model import LassoLarsCV

# %%
pred_train, pred_test, tar_train, tar_test = train_test_split(bp_df.T, gr_truth.values.ravel(), test_size=0.3, random_state=123)

# %%
model = LassoLarsCV(cv=10, precompute=True).fit(pred_train,tar_train)
# Out:
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 56 iterations, i.e. alpha=3.489e-03, with an active set of 44 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 91 iterations, i.e. alpha=2.564e-03, with an active set of 63 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# ...

# %%
z = dict(zip(bp_df.T.columns, model.coef_))

# %%
print(list(z.values()).count(0))
print(len(z))
# Out:
# 5059
# 5103

# %%
m_log_alphas = -np.log10(model.alphas_) # contain alpha values 
ax = plt.gca() # set up axes 
plt.plot(m_log_alphas, model.coef_path_.T) # change in regression values (transposed)
plt.axvline(-np.log10(model.alpha_), linestyle='--',color='k',label='alpha CV')
plt.ylabel('Regression Coefficients')
plt.xlabel('-log(alpha)')
plt.title('Regression Coefficients Progression for Lasso Paths')
# Out:
# Text(0.5,1,'Regression Coefficients Progression for Lasso Paths')

# %%
# plot mean square error for each fold 
m_log_alphascv = -np.log10(model.cv_alphas_)
plt.figure()
plt.plot(m_log_alphascv, model.cv_mse_path_, ':') # for each cross validation 
plt.plot(m_log_alphascv, model.cv_mse_path_.mean(axis=-1), 'k', label='Average across the folds', linewidth=2)
plt.axvline(-np.log10(model.alpha_), linestyle='--',color='k', label='alpha CV')
plt.legend()
plt.xlabel('-log(alpha)')
plt.ylabel('Mean squared error')
plt.title('Mean squared error on each fold')
# Out:
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function cv_mse_path_ is deprecated; Attribute ``cv_mse_path_`` is deprecated in 0.18 and will be removed in 0.20. Use ``mse_path_`` instead
#   warnings.warn(msg, category=DeprecationWarning)
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function cv_mse_path_ is deprecated; Attribute ``cv_mse_path_`` is deprecated in 0.18 and will be removed in 0.20. Use ``mse_path_`` instead
#   warnings.warn(msg, category=DeprecationWarning)
# Text(0.5,1,'Mean squared error on each fold')

# %%
# Mean square error (MSE) from training and test data 
from sklearn.metrics import mean_squared_error 
train_error = mean_squared_error(tar_train, model.predict(pred_train))
test_error = mean_squared_error(tar_test, model.predict(pred_test))
print('training data MSE')
print(train_error)
print('test data MSE')
print(test_error)
# Out:
# training data MSE
# 0.08042621640209849
# test data MSE
# 0.1366086688869263

# %%
# R-square from training and test data 
rsquared_train = model.score(pred_train, tar_train)
rsquared_test = model.score(pred_test, tar_test)
print('training data R-square')
print(rsquared_train)
print('test data R-square')
print(rsquared_test)
# Out:
# training data R-square
# 0.6587601176002307
# test data R-square
# 0.4446416936621005

# %% [markdown]
# ### Combined GO matrix

# %%
lasso_steps = [('pca', PCA(n_components=0.95)), ('m', Lasso(alpha=0))]
lasso = Pipeline(steps=lasso_steps)
lasso.fit(go_df.T, gr_truth.values.ravel())
scores = cross_val_score(lasso, go_df.T, gr_truth.values.ravel())
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/pipeline.py:250: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params)
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:477: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/pipeline.py:250: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# ...

# %%
# Train test split 
pred_train, pred_test, tar_train, tar_test = train_test_split(go_df.T, gr_truth.values.ravel(), test_size=0.3, random_state=123)

# %%
go_model = LassoLarsCV(cv=10, precompute=False).fit(pred_train,tar_train)
# Out:
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=5.550e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=3.861e-03, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# ...

# %%
z = dict(zip(go_df.T.columns, go_model.coef_))

# %%
print(list(z.values()).count(0))
print(len(z))
# Out:
# 6644
# 6700

# %%
m_log_alphas = -np.log10(go_model.alphas_) # contain alpha values 
ax = plt.gca() # set up axes 
plt.plot(m_log_alphas, go_model.coef_path_.T) # change in regression values (transposed)
plt.axvline(-np.log10(go_model.alpha_), linestyle='--',color='k',label='alpha CV')
plt.ylabel('Regression Coefficients')
plt.xlabel('-log(alpha)')
plt.title('Regression Coefficients Progression for Lasso Paths')
# Out:
# Text(0.5,1,'Regression Coefficients Progression for Lasso Paths')

# %%
# plot mean square error for each fold 
m_log_alphascv = -np.log10(go_model.cv_alphas_)
plt.figure()
plt.plot(m_log_alphascv, go_model.cv_mse_path_, ':') # for each cross validation 
plt.plot(m_log_alphascv, go_model.cv_mse_path_.mean(axis=-1), 'k', label='Average across the folds', linewidth=2)
plt.axvline(-np.log10(go_model.alpha_), linestyle='--',color='k', label='alpha CV')
plt.legend()
plt.xlabel('-log(alpha)')
plt.ylabel('Mean squared error')
plt.title('Mean squared error on each fold')
# Out:
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function cv_mse_path_ is deprecated; Attribute ``cv_mse_path_`` is deprecated in 0.18 and will be removed in 0.20. Use ``mse_path_`` instead
#   warnings.warn(msg, category=DeprecationWarning)
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function cv_mse_path_ is deprecated; Attribute ``cv_mse_path_`` is deprecated in 0.18 and will be removed in 0.20. Use ``mse_path_`` instead
#   warnings.warn(msg, category=DeprecationWarning)
# Text(0.5,1,'Mean squared error on each fold')

# %%
# Mean square error (MSE) from training and test data 
train_error = mean_squared_error(tar_train, go_model.predict(pred_train))
test_error = mean_squared_error(tar_test, go_model.predict(pred_test))
print('training data MSE')
print(train_error)
print('test data MSE')
print(test_error)
# Out:
# training data MSE
# 0.05676745371321206
# test data MSE
# 0.13881540846172344

# %%
# R-square from training and test data 
rsquared_train = go_model.score(pred_train, tar_train)
rsquared_test = go_model.score(pred_test, tar_test)
print('training data R-square')
print(rsquared_train)
print('test data R-square')
print(rsquared_test)
# Out:
# training data R-square
# 0.7591417314426172
# test data R-square
# 0.43567058543907444
